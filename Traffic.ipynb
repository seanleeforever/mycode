# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import folium
from folium import plugins

# %%
# read from LAcity.org JSON link and save as data frame
df=pd.read_json("https://data.lacity.org/resource/d5tf-ez2w.json")

# %%
#Check the Data structure
df.head()
# Out:
#        dr_no                date_rptd                 date_occ  time_occ
# 0  190319651  2019-08-24T00:00:00.000  2019-08-24T00:00:00.000       450  \
# 1  190319680  2019-08-30T00:00:00.000  2019-08-30T00:00:00.000      2320
# 2  190413769  2019-08-25T00:00:00.000  2019-08-25T00:00:00.000       545
# 3  190127578  2019-11-20T00:00:00.000  2019-11-20T00:00:00.000       350
# 4  190319695  2019-08-30T00:00:00.000  2019-08-30T00:00:00.000      2100
#
#    area   area_name  rpt_dist_no  crm_cd        crm_cd_desc
# 0     3   Southwest          356     997  TRAFFIC COLLISION  \
# 1     3   Southwest          355     997  TRAFFIC COLLISION
# 2     4  Hollenbeck          422     997  TRAFFIC COLLISION
# 3     1     Central          128     997  TRAFFIC COLLISION
# 4     3   Southwest          374     997  TRAFFIC COLLISION
#
#                               mocodes  ...  premis_desc
# 0            3036 3004 3026 3101 4003  ...       STREET  \
# 1  3037 3006 3028 3030 3039 3101 4003  ...       STREET
# 2            3101 3401 3701 3006 3030  ...       STREET
# 3       0605 3101 3401 3701 3011 3034  ...       STREET
# 4       0605 4025 3037 3004 3025 3101  ...       STREET
#
#                           location                        cross_street
# 0  JEFFERSON                    BL     NORMANDIE                    AV  \
# 1  JEFFERSON                    BL                          W  WESTERN
# 2                      N  BROADWAY  W  EASTLAKE                     AV
# 3                              1ST                             CENTRAL
# 4            MARTIN LUTHER KING JR     ARLINGTON                    AV
#
#                                           location_1
# 0  {'latitude': '34.0255', 'longitude': '-118.300...  \
# 1  {'latitude': '34.0256', 'longitude': '-118.308...
# 2  {'latitude': '34.0738', 'longitude': '-118.207...
# 3  {'latitude': '34.0492', 'longitude': '-118.239...
# 4  {'latitude': '34.0108', 'longitude': '-118.318...
#
#   :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv
# 0                     22724.0                       691.0  \
# 1                     23079.0                       686.0
# 2                     23448.0                       488.0
# 3                     22728.0                       536.0
# 4                     22725.0                       747.0
#
#   :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx
# 0                       916.0                         7.0  \
# 1                       919.0                         7.0
# 2                       516.0                         NaN
# 3                      1502.0                         NaN
# 4                      1017.0                         7.0
#
#    :@computed_region_kqwf_mjcx  :@computed_region_2dna_qi2s
# 0                         14.0                         32.0
# 1                         12.0                         19.0
# 2                         11.0                          1.0
# 3                          9.0                         28.0
# 4                         14.0                         35.0
#
# [5 rows x 24 columns]

# %%
#get the geolocaiton information, which is under location1 attribuate as a dictionary.
#extract that dictionary and add onto the dataframe
df2=df.join(df.location_1.apply(pd.Series))
df2
# Out:
#          dr_no                date_rptd                 date_occ  time_occ
# 0    190319651  2019-08-24T00:00:00.000  2019-08-24T00:00:00.000       450  \
# 1    190319680  2019-08-30T00:00:00.000  2019-08-30T00:00:00.000      2320
# 2    190413769  2019-08-25T00:00:00.000  2019-08-25T00:00:00.000       545
# 3    190127578  2019-11-20T00:00:00.000  2019-11-20T00:00:00.000       350
# 4    190319695  2019-08-30T00:00:00.000  2019-08-30T00:00:00.000      2100
# ..         ...                      ...                      ...       ...
# 995  190913230  2019-07-03T00:00:00.000  2019-07-02T00:00:00.000      1230
# 996  191419332  2019-09-02T00:00:00.000  2019-08-28T00:00:00.000      1035
# 997  191613458  2019-09-03T00:00:00.000  2019-09-02T00:00:00.000      1330
# 998  191818861  2019-09-02T00:00:00.000  2019-08-10T00:00:00.000      2200
# 999  190913466  2019-07-08T00:00:00.000  2019-07-08T00:00:00.000      1430
#
#      area   area_name  rpt_dist_no  crm_cd        crm_cd_desc
# 0       3   Southwest          356     997  TRAFFIC COLLISION  \
# 1       3   Southwest          355     997  TRAFFIC COLLISION
# 2       4  Hollenbeck          422     997  TRAFFIC COLLISION
# 3       1     Central          128     997  TRAFFIC COLLISION
# 4       3   Southwest          374     997  TRAFFIC COLLISION
# ..    ...         ...          ...     ...                ...
# 995     9    Van Nuys          914     997  TRAFFIC COLLISION
# 996    14     Pacific         1495     997  TRAFFIC COLLISION
# 997    16    Foothill         1653     997  TRAFFIC COLLISION
# 998    18   Southeast         1806     997  TRAFFIC COLLISION
# 999     9    Van Nuys          985     997  TRAFFIC COLLISION
#
#                                      mocodes  ...
# 0                   3036 3004 3026 3101 4003  ...  \
# 1         3037 3006 3028 3030 3039 3101 4003  ...
# 2                   3101 3401 3701 3006 3030  ...
# 3              0605 3101 3401 3701 3011 3034  ...
# 4              0605 4025 3037 3004 3025 3101  ...
# ..                                       ...  ...
# 995  3006 4009 3030 3028 3037 3101 3401 3701  ...
# 996                                     0605  ...
# 997                                     0605  ...
# 998       0605 3036 3006 3028 3030 3101 4018  ...
# 999                                      NaN  ...
#
#                                             location_1
# 0    {'latitude': '34.0255', 'longitude': '-118.300...  \
# 1    {'latitude': '34.0256', 'longitude': '-118.308...
# 2    {'latitude': '34.0738', 'longitude': '-118.207...
# 3    {'latitude': '34.0492', 'longitude': '-118.239...
# 4    {'latitude': '34.0108', 'longitude': '-118.318...
# ..                                                 ...
# 995  {'latitude': '34.2012', 'longitude': '-118.457...
# 996  {'latitude': '33.9542', 'longitude': '-118.389...
# 997  {'latitude': '34.2503', 'longitude': '-118.411...
# 998  {'latitude': '33.9529', 'longitude': '-118.260...
# 999  {'latitude': '34.1488', 'longitude': '-118.441...
#
#     :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv
# 0                       22724.0                       691.0  \
# 1                       23079.0                       686.0
# 2                       23448.0                       488.0
# 3                       22728.0                       536.0
# 4                       22725.0                       747.0
# ..                          ...                         ...
# 995                     19733.0                       219.0
# 996                     23676.0                      2340.0
# 997                     18907.0                        34.0
# 998                     22351.0                       799.0
# 999                     19736.0                       334.0
#
#      :@computed_region_tatf_ua23 :@computed_region_ur2y_g4cx
# 0                          916.0                         7.0  \
# 1                          919.0                         7.0
# 2                          516.0                         NaN
# 3                         1502.0                         NaN
# 4                         1017.0                         7.0
# ..                           ...                         ...
# 995                        288.0                         NaN
# 996                        791.0                        12.0
# 997                        451.0                         NaN
# 998                       1173.0                         7.0
# 999                        682.0                         NaN
#
#     :@computed_region_kqwf_mjcx :@computed_region_2dna_qi2s latitude
# 0                          14.0                        32.0  34.0255  \
# 1                          12.0                        19.0  34.0256
# 2                          11.0                         1.0  34.0738
# 3                           9.0                        28.0  34.0492
# 4                          14.0                        35.0  34.0108
# ..                          ...                         ...      ...
# 995                         3.0                        18.0  34.2012
# 996                        10.0                        16.0  33.9542
# 997                         1.0                        11.0  34.2503
# 998                        13.0                        45.0  33.9529
# 999                         7.0                        83.0  34.1488
#
#      longitude                                      human_address
# 0    -118.3002  {"address": "", "city": "", "state": "", "zip"...
# 1    -118.3089  {"address": "", "city": "", "state": "", "zip"...
# 2    -118.2078  {"address": "", "city": "", "state": "", "zip"...
# 3    -118.2391  {"address": "", "city": "", "state": "", "zip"...
# 4    -118.3182  {"address": "", "city": "", "state": "", "zip"...
# ..         ...                                                ...
# 995  -118.4574  {"address": "", "city": "", "state": "", "zip"...
# 996  -118.3892  {"address": "", "city": "", "state": "", "zip"...
# 997  -118.4112  {"address": "", "city": "", "state": "", "zip"...
# 998  -118.2608  {"address": "", "city": "", "state": "", "zip"...
# 999  -118.4411  {"address": "", "city": "", "state": "", "zip"...
#
# [1000 rows x 27 columns]

# %%
#only care about  geo locationd
noCareList = df2.columns

# %%
toDrop=['area','date_occ','time_occ','dr_no','date_rptd',
       'rpt_dist_no', 'crm_cd', 'crm_cd_desc', 'mocodes', 'vict_age',
       'vict_sex', 'vict_descent', 'premis_cd', 'premis_desc', 'location',
       'cross_street', 'location_1', ':@computed_region_qz3q_ghft',
       ':@computed_region_k96s_3jcv', ':@computed_region_tatf_ua23',
       ':@computed_region_ur2y_g4cx', ':@computed_region_kqwf_mjcx',
       ':@computed_region_2dna_qi2s',
       'human_address']
df2.drop(toDrop, inplace=True, axis=1)
df2
# Out:
#       area_name latitude  longitude
# 0     Southwest  34.0255  -118.3002
# 1     Southwest  34.0256  -118.3089
# 2    Hollenbeck  34.0738  -118.2078
# 3       Central  34.0492  -118.2391
# 4     Southwest  34.0108  -118.3182
# ..          ...      ...        ...
# 995    Van Nuys  34.2012  -118.4574
# 996     Pacific  33.9542  -118.3892
# 997    Foothill  34.2503  -118.4112
# 998   Southeast  33.9529  -118.2608
# 999    Van Nuys  34.1488  -118.4411
#
# [1000 rows x 3 columns]

# %%
#rename the column 
df2 = df2.rename(columns={'dr_no': 'Driver License Number', 'area_name':'Area Name', 'date_rptd': 'Date Reported', 'latitude': 'Latitude', 'longitude': 'Longitude'})
df2
# Out:
#       Area Name Latitude  Longitude
# 0     Southwest  34.0255  -118.3002
# 1     Southwest  34.0256  -118.3089
# 2    Hollenbeck  34.0738  -118.2078
# 3       Central  34.0492  -118.2391
# 4     Southwest  34.0108  -118.3182
# ..          ...      ...        ...
# 995    Van Nuys  34.2012  -118.4574
# 996     Pacific  33.9542  -118.3892
# 997    Foothill  34.2503  -118.4112
# 998   Southeast  33.9529  -118.2608
# 999    Van Nuys  34.1488  -118.4411
#
# [1000 rows x 3 columns]

# %%
#get an idea of how many accidents happen at some location
accidents=df2.groupby(['Latitude','Longitude','Area Name']).size().reset_index(name='Count').sort_values(by='Count', ascending=False)
accidents.Count.max()
# Out:
# 3

# %%
#well. that is too specific, 4 decimal place is probabily too narrow, that's about 10 meters, let's increase that to 2 decimal
accidents.drop('Count',inplace=True, axis=1)
accidents[['Latitude','Longitude']]=accidents[['Latitude','Longitude']].astype(float).round(decimals=2)

ac=accidents.groupby(['Latitude','Longitude','Area Name']).size().reset_index(name='Count').sort_values(by='Count', ascending=False)
ac.Count.max()
# Out:
# 8

# %%
#give it some colors based on the number of accidents at that location
ac['Color'] = "grey"
ac['Color'] = ac['Count'].apply(lambda Count: "black" if Count >= 7 else
                              "maroon" if Count >=5 and Count < 7  else
                              "red" if Count >=5 and Count < 5  else
                              "salmon" if Count >=3 and Count <4 else
                              "mistyrose" if Count >=2 and Count < 3 else
                              "grey")

# %%
#give it some size based on the number of accidents at that location
ac['Size']=ac['Count'].apply(lambda Count: 10 if Count >= 7 else
                              8 if Count >=5 and Count < 7  else
                              6 if Count >=5 and Count < 5  else
                              4 if Count >=3 and Count <4 else
                              2 if Count >=2 and Count < 3 else
                              1)

# %%
ac
# Out:
#      Latitude  Longitude  Area Name  Count   Color  Size
# 297     34.10    -118.33  Hollywood      8   black    10
# 296     34.10    -118.34  Hollywood      8   black    10
# 200     34.05    -118.26    Central      7   black    10
# 203     34.05    -118.24    Central      6  maroon     8
# 83      33.99    -118.27     Newton      6  maroon     8
# ..        ...        ...        ...    ...     ...   ...
# 247     34.07    -118.25    Central      1    grey     1
# 246     34.07    -118.26    Rampart      1    grey     1
# 245     34.07    -118.27    Rampart      1    grey     1
# 242     34.07    -118.30    Olympic      1    grey     1
# 541     34.32    -118.42    Mission      1    grey     1
#
# [542 rows x 6 columns]

# %%
ac_map=folium.Map([34.03438,-118.24256],zoom_start=11)
for lat,lon,area,color,count,size in zip(ac['Latitude'],ac['Longitude'],ac['Area Name'],ac['Color'],ac['Count'],ac['Size']):
     folium.CircleMarker([lat, lon],
                            popup='<h5>%s</h5>\n Number Accidents: %s' %(area,count),
                            radius=size,
                            color='b',
                            fill=True,
                            fill_opacity=0.7,
                            fill_color=color,
                           ).add_to(ac_map)
        
ac_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98871d39414a96e45c13149c6b858385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98871d39414a96e45c13149c6b858385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98871d39414a96e45c13149c6b858385 = L.map(
#                 &quot;map_98871d39414a96e45c13149c6b858385&quot;,
#                 {
#                     center: [34.03438, -118.24256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6e0c37ef071c453b04af63ff63164a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#             var circle_marker_e49d58fae736090ae1b82a1d78041c51 = L.circleMarker(
#                 [34.1, -118.33],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_fc7cf2f43a544baf40478530099acadd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9da5222bf833814a0e4156a219ae7fc = $(`&lt;div id=&quot;html_a9da5222bf833814a0e4156a219ae7fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Hollywood&lt;/h5&gt;  Number Accidents: 8&lt;/div&gt;`)[0];
#                 popup_fc7cf2f43a544baf40478530099acadd.setContent(html_a9da5222bf833814a0e4156a219ae7fc);
#
#
#
#         circle_marker_e49d58fae736090ae1b82a1d78041c51.bindPopup(popup_fc7cf2f43a544baf40478530099acadd)
#         ;
#
#
#
#
#             var circle_marker_87cdb68e1c2a3991d0412b1bc9873faa = L.circleMarker(
#                 [34.1, -118.34],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_946ab4da68f2c648b8203ebabc11a599 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab8b944dd8255f9a7671e9b130c3098a = $(`&lt;div id=&quot;html_ab8b944dd8255f9a7671e9b130c3098a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Hollywood&lt;/h5&gt;  Number Accidents: 8&lt;/div&gt;`)[0];
#                 popup_946ab4da68f2c648b8203ebabc11a599.setContent(html_ab8b944dd8255f9a7671e9b130c3098a);
#
#
#
#         circle_marker_87cdb68e1c2a3991d0412b1bc9873faa.bindPopup(popup_946ab4da68f2c648b8203ebabc11a599)
#         ;
#
#
#
#
#             var circle_marker_6b403af64114c17d95f876c6a989e91a = L.circleMarker(
#                 [34.05, -118.26],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_d1b67339d0415b337030b91ba568e9c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b15f5a3c95cc997d7860a97c95877f8 = $(`&lt;div id=&quot;html_5b15f5a3c95cc997d7860a97c95877f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Central&lt;/h5&gt;  Number Accidents: 7&lt;/div&gt;`)[0];
#                 popup_d1b67339d0415b337030b91ba568e9c4.setContent(html_5b15f5a3c95cc997d7860a97c95877f8);
#
#
#
#         circle_marker_6b403af64114c17d95f876c6a989e91a.bindPopup(popup_d1b67339d0415b337030b91ba568e9c4)
#         ;
#
#
#
#
#             var circle_marker_fb413944108060af4ce68c3cce335252 = L.circleMarker(
#                 [34.05, -118.24],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quo

# %%
# convert to  format for heatmap, dont' reallly care about the small accidents 
ac2=ac.loc[ac['Count']>=2]
ac2.reset_index(drop = True)
# Out:
#      Latitude  Longitude   Area Name  Count      Color  Size
# 0       34.10    -118.33   Hollywood      8      black    10
# 1       34.10    -118.34   Hollywood      8      black    10
# 2       34.05    -118.26     Central      7      black    10
# 3       34.05    -118.24     Central      6     maroon     8
# 4       33.99    -118.27      Newton      6     maroon     8
# ..        ...        ...         ...    ...        ...   ...
# 211     33.96    -118.27   Southeast      2  mistyrose     2
# 212     34.22    -118.37    Foothill      2  mistyrose     2
# 213     33.96    -118.26   Southeast      2  mistyrose     2
# 214     34.31    -118.47     Mission      2  mistyrose     2
# 215     34.24    -118.48  Devonshire      2  mistyrose     2
#
# [216 rows x 6 columns]

# %%
ac2_data = ac2[['Latitude', 'Longitude']].values

# plot heatmap
ac_map.add_children(plugins.HeatMap(ac2_data, radius=15))
ac_map
# Out:
# /tmp/ipykernel_86794/1356928257.py:4: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   ac_map.add_children(plugins.HeatMap(ac2_data, radius=15))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98871d39414a96e45c13149c6b858385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98871d39414a96e45c13149c6b858385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98871d39414a96e45c13149c6b858385 = L.map(
#                 &quot;map_98871d39414a96e45c13149c6b858385&quot;,
#                 {
#                     center: [34.03438, -118.24256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6e0c37ef071c453b04af63ff63164a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#             var circle_marker_e49d58fae736090ae1b82a1d78041c51 = L.circleMarker(
#                 [34.1, -118.33],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_fc7cf2f43a544baf40478530099acadd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9da5222bf833814a0e4156a219ae7fc = $(`&lt;div id=&quot;html_a9da5222bf833814a0e4156a219ae7fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Hollywood&lt;/h5&gt;  Number Accidents: 8&lt;/div&gt;`)[0];
#                 popup_fc7cf2f43a544baf40478530099acadd.setContent(html_a9da5222bf833814a0e4156a219ae7fc);
#
#
#
#         circle_marker_e49d58fae736090ae1b82a1d78041c51.bindPopup(popup_fc7cf2f43a544baf40478530099acadd)
#         ;
#
#
#
#
#             var circle_marker_87cdb68e1c2a3991d0412b1bc9873faa = L.circleMarker(
#                 [34.1, -118.34],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_946ab4da68f2c648b8203ebabc11a599 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab8b944dd8255f9a7671e9b130c3098a = $(`&lt;div id=&quot;html_ab8b944dd8255f9a7671e9b130c3098a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Hollywood&lt;/h5&gt;  Number Accidents: 8&lt;/div&gt;`)[0];
#                 popup_946ab4da68f2c648b8203ebabc11a599.setContent(html_ab8b944dd8255f9a7671e9b130c3098a);
#
#
#
#         circle_marker_87cdb68e1c2a3991d0412b1bc9873faa.bindPopup(popup_946ab4da68f2c648b8203ebabc11a599)
#         ;
#
#
#
#
#             var circle_marker_6b403af64114c17d95f876c6a989e91a = L.circleMarker(
#                 [34.05, -118.26],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_98871d39414a96e45c13149c6b858385);
#
#
#         var popup_d1b67339d0415b337030b91ba568e9c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b15f5a3c95cc997d7860a97c95877f8 = $(`&lt;div id=&quot;html_5b15f5a3c95cc997d7860a97c95877f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Central&lt;/h5&gt;  Number Accidents: 7&lt;/div&gt;`)[0];
#                 popup_d1b67339d0415b337030b91ba568e9c4.setContent(html_5b15f5a3c95cc997d7860a97c95877f8);
#
#
#
#         circle_marker_6b403af64114c17d95f876c6a989e91a.bindPopup(popup_d1b67339d0415b337030b91ba568e9c4)
#         ;
#
#
#
#
#             var circle_marker_fb413944108060af4ce68c3cce33525

# %%
from flask import Flask

app = Flask(__name__)

# HTTP GET /
# create a map that returns hershey 
@app.route('/')
def index():
    return ac_map._repr_html_()

if __name__ == '__main__':
    app.run(host="0.0.0.0", port=2224, debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:2224
#  * Running on http://10.12.7.231:2224
# Press CTRL+C to quit
#  * Restarting with stat
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 1042, in launch_instance
#     app.initialize(argv)
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 113, in inner
#     return method(app, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 678, in initialize
#     self.init_sockets()
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 317, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 252, in _bind_socket
#     return self._try_bind_socket(s, port)
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 228, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py", line 301, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
