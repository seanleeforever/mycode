# %%
#!/usr/bin/python3
"""Alta3 Research | RZFeeser@alta3.com
   Challenge Solution 01 - JSON to CSV"""

import pandas as pd

# create a dataframe from json
df = pd.read_json("5movies.json")

# writeout dataframe to CSV

df.to_csv("5movies-translated-from-json.csv")
display (df["Budget"])
df["Budget"].to_csv("5movies-translated-from-json_budgetOnly.csv")
# Out:
# Intolerance: Love's Struggle Throughout the Ages      385907.0
# Over the Hill to the Poorhouse                        100000.0
# The Big Parade                                        245000.0
# Metropolis                                           6000000.0
# Pandora's Box                                              NaN
# Name: Budget, dtype: float64

# %%
df = pd.read_csv("5movies.csv")

df.to_excel("5movies-translated-from-json.xlsx")
display(df)
df.sort_values(["Duration"], ascending=False,ignore_index=True)
df.sort_values(["Duration"], ascending=False,ignore_index=True).to_excel("5movies-translated-from-json_sortbyDuration.xlsx")
# Out:
#                                                Title  Year
# 0  Intolerance: Love's Struggle Throughout the Ages   1916  \
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration
# 0    Drama|History|War      NaN      USA      Not Rated       123  \
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1
# 0          1.33   385907.0             NaN  ...                      436  \
# ...

# %%
df = pd.read_json("5movies.json")
display (df)
df.to_excel("5movies-translated-from-json.xlsx")
df.iloc[0]
# Out:
#                                                    Year               Genres
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War  \
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country
# Intolerance: Love's Struggle Throughout the Ages      None      USA  \
# Over the Hill to the Poorhouse                        None      USA
# The Big Parade                                        None      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
#
#                                                   Content Rating  Duration
# ...

# %%
    df.index
# Out:
# Index(['Intolerance: Love's Struggle Throughout the Ages ',
#        'Over the Hill to the Poorhouse ', 'The Big Parade ', 'Metropolis ',
#        'Pandora's Box '],
#       dtype='object')
